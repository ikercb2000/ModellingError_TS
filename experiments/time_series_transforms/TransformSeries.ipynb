# %% [markdown]
# # Transforming Series

# %%
# Other modules

import numpy as np
import keras
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from scipy.stats import gumbel_r
from scipy.stats import lognorm

# %% [markdown]
# ### Gumbel

# %% [markdown]
# Expected Value: $E(X)=\mu+\beta\gamma$ where $\gamma$ is Euler-Mascheroni constant
#
# Median Value: $q^{0.5}_X = \mu - \beta \ln(\ln(2))$
#
# Difference: $E(X)-q^{0.5}_X = \beta (\gamma+\ln(\ln(2))) \approx \beta \times 0.210703$

# %%
# Seed

seed = 3254
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)


# Loss functions dictionary

loss_functions = {
    "L1": "mae",
    "L2": "mse",
    "Huber": keras.losses.Huber(delta=0.5)
}

# NN and series specifications

seq_length = 500   # number of time steps (moments)
num_examples = 100  # number of examples (noise realizations)
batch_size = 16
epochs = 250
learning_rate = 0.01
x = np.linspace(0, 1, seq_length)
y_clean = x**2
loc=0
scale=1  # for lower values, difference seems random, but for higher values, we approach the expected
theory_mean = scale*np.euler_gamma
theory_median = scale*np.log(np.log(2))

mean_array = np.array([theory_mean]*(num_examples * seq_length)).reshape(num_examples, seq_length)
median_array = np.array([theory_median]*(num_examples * seq_length)).reshape(num_examples, seq_length)

# Create arrays

x_repeated = np.tile(x, (num_examples, 1))
np.random.seed(32)
noise = np.random.gumbel(loc=loc, scale=scale, size=num_examples * seq_length).reshape(num_examples, seq_length)
data = np.tile(y_clean, (num_examples, 1)) + noise - np.array([theory_mean]*(num_examples * seq_length)).reshape(num_examples, seq_length)
target = np.tile(y_clean, (num_examples, 1))

# Create and estimate models

model = keras.models.Sequential([
    keras.layers.Input(shape=(seq_length,)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(seq_length, activation='linear')
])

optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
predict = {}

for title, selected_loss in loss_functions.items():
    
    model.compile(optimizer=optimizer, loss=selected_loss)
    model.fit(x=x_repeated, y=data, batch_size=batch_size, epochs=epochs)
    predictions = model.predict(x_repeated)
    predict[title] = predictions[0]
   
    plt.figure(figsize=(10, 6))
    plt.plot(x, y_clean, 'k--', linewidth=2, label='Clean Signal')
    plt.plot(x, data[0,:], 'r--', linewidth=2, label='Noisy Signal')
    plt.plot(x, predict[title], label=f'Prediction', alpha=0.7)
    plt.xlabel("Time (or Moment Index)")
    plt.ylabel("Signal Value")
    plt.title(f"Neural Network Predictions Over Time for {title} Loss")
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.tight_layout()
    plt.show()
# Out:
# Epoch 1/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0340
# Epoch 2/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9940
# Epoch 3/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9872
# Epoch 4/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9813
# Epoch 5/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9765
# Epoch 6/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9727
# Epoch 7/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9698
# Epoch 8/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9676
# Epoch 9/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9660
# Epoch 10/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9648
# Epoch 11/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9639
# Epoch 12/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9632
# Epoch 13/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9628
# Epoch 14/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9624
# Epoch 15/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9622
# Epoch 16/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9620
# Epoch 17/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9619
# Epoch 18/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9619
# Epoch 19/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9618
# Epoch 20/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9618
# Epoch 21/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9618
# Epoch 22/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9619
# Epoch 23/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9619
# Epoch 24/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9619
# Epoch 25/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9619
# Epoch 26/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9620
# Epoch 27/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.
250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 123/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 124/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 125/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3707
# Epoch 126/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 127/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 128/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 129/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 130/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 131/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3707
# Epoch 132/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 133/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3707
# Epoch 134/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3707
# Epoch 135/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 136/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 137/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 138/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3707
# Epoch 139/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3707
# Epoch 140/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3707
# Epoch 141/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3707
# Epoch 142/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 143/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 144/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3707
# Epoch 145/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 146/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 147/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3707
# Epoch 148/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 149/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 150/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 151/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 152/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 153/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 154/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 155/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 156/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 157/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3707
# Epoch 158/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 159/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 160/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 161/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 162/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3707
# Epoch 163/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 164/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 165/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 166/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 167/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 168/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 169/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 170/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 171/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 172/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 173/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 174/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3707
# Epoch 175/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3707
# Epoch 176/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3707
# Epoch 177/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 178/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3707
# Epoch 179/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3707
# Epoch 180/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3707
# Epoch 181/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 182/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 183/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3707
# Epoch 184/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3707
# Epoch 185/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 186/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 187/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 188/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 189/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3706
# Epoch 190/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 191/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 192/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 193/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3706
# Epoch 194/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3706
# Epoch 195/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 196/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 197/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3706
# Epoch 198/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 199/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 200/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 201/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 202/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 203/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 204/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 205/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 206/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3706
# Epoch 207/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3706
# Epoch 208/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3706
# Epoch 209/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 210/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3706
# Epoch 211/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 212/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 213/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 214/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 215/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 216/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 217/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 218/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 219/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 220/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3706
# Epoch 221/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 222/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3706
# Epoch 223/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 224/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3706
# Epoch 225/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 226/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 227/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3706
# Epoch 228/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3706
# Epoch 229/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 230/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 231/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 232/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 233/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 234/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 235/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 236/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 237/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 238/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3706
# Epoch 239/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 240/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 241/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 242/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 243/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3706
# Epoch 244/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# Epoch 245/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 246/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 247/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3706
# Epoch 248/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 249/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3706
# Epoch 250/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3706
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
for title in loss_functions.keys():
    error = predict[title] - y_clean
    plt.figure(figsize=(10, 6))
    plt.plot(x, error, label=f'Prediction Error for {title}', alpha=0.7)
    plt.xlabel("Time (or Moment Index)")
    plt.ylabel("Error Value")
    plt.title(f"Prediction Error Over Time for {title} Loss")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y_clean, 'k--', linewidth=2, label='Clean Signal')
plt.plot(x, predict["L1"], label=f'Prediction for L1', alpha=0.7)
plt.plot(x, predict["L2"], label=f'Prediction for L2', alpha=0.7)
plt.xlabel("Time (or Moment Index)")
plt.ylabel("Signal Value")
plt.title(f"Neural Network Predictions Over Time for L1 and L2 Losses")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# TODO: Se podría hacer un suavizado o una regresión suave

# %%
x_pdf = np.linspace(-5, 10, 1000)
pdf = gumbel_r.pdf(x_pdf, loc=loc, scale=scale)
mean_gumbel = gumbel_r.mean(loc=loc, scale=scale)
median_gumbel = gumbel_r.median(loc=loc, scale=scale)

# Plot the PDF
plt.figure(figsize=(10, 6))
plt.plot(x_pdf, pdf, label='Gumbel PDF', color='blue')
plt.axvline(mean_gumbel, color='red', linestyle='--', label=f'Mean: {mean_gumbel:.2f}')
plt.axvline(median_gumbel, color='green', linestyle='--', label=f'Median: {median_gumbel:.2f}')
plt.xlabel('x')
plt.ylabel('Density')
plt.title('Gumbel Distribution (loc=0, scale=1)')
plt.legend()
plt.grid(True)
plt.show()

# %%
diff_series = np.array(predict["L2"]-predict["L1"])
diff_mean = np.mean(predict["L2"]-predict["L1"])
mean_rounded = str(round(diff_mean,4))
theoretical_diff = scale*(np.euler_gamma+np.log(np.log(2)))

print("Observed Mean Difference: ",mean_rounded)
print("Theoretical Difference: ", theoretical_diff)

plt.figure(figsize=(10, 6))
plt.plot(x, diff_series, label=f'Prediction Differences L2 vs L1', alpha=0.7)
plt.hlines(y=diff_mean,label=f'Mean Difference L2 - L1 = {mean_rounded}',xmin=0,xmax=1)
plt.xlabel("Time (or Moment Index)")
plt.ylabel("Signal Value")
plt.title(f"Neural Network Predictions Over Time for{title} Loss")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()
# Out:
# Observed Mean Difference:  0.2129
# Theoretical Difference:  0.21070274431986852

# %% [markdown]
# ### Log-normal

# %% [markdown]
# Expected Value: $E(X)=\exp(\mu+\sigma^2/2)$
#
# Median Value: $q^{0.5}_X = \exp(\mu)$
#
# Difference: $E(X)-q^{0.5}_X = \exp(\mu+\sigma^2/2)-\exp(\mu) = \exp(\mu)(\exp(\sigma^2/2)-1) \approx 0.35914$ for $\mu=0,\sigma=1$

# %% [markdown]
# - Solo mostrar arrays
# - Gráficos que se puedan poner uno encima de otro
# - Mostrar diferencias

# %%
# Seed

seed = 526
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)

# Loss functions dictionary

loss_functions = {
    "L1": "mae",
    "L2": "mse",
    "Huber": keras.losses.Huber(delta=0.5)
}

# NN and series specifications

seq_length = 500   # number of time steps (moments)
num_examples = 100  # number of examples (noise realizations)
batch_size = 16
epochs = 250
learning_rate = 0.01
x = np.linspace(0, 1, seq_length)
y_clean = x**2
mean=0
sigma=1  # for lower values, results vary more or less randomly, but with high values it seems to be near the expected
theory_mean = np.exp(mean+(sigma**2)/2)
theory_median = np.exp(mean)

mean_array = np.array([theory_mean]*(num_examples * seq_length)).reshape(num_examples, seq_length)
median_array = np.array([theory_median]*(num_examples * seq_length)).reshape(num_examples, seq_length)

# Create arrays

x_repeated = np.tile(x, (num_examples, 1))
np.random.seed(32)
noise = np.random.lognormal(mean=mean, sigma=sigma, size=num_examples * seq_length).reshape(num_examples, seq_length)
data = np.tile(y_clean, (num_examples, 1)) + noise - mean_array # meadian_array
target = np.tile(y_clean, (num_examples, 1))

# Create and estimate models

model = keras.models.Sequential([
    keras.layers.Input(shape=(seq_length,)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(seq_length, activation='linear')
])

optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
predict = {}

for title, selected_loss in loss_functions.items():
    
    model.compile(optimizer=optimizer, loss=selected_loss)
    model.fit(x=x_repeated, y=data, batch_size=batch_size, epochs=epochs)
    predictions = model.predict(x_repeated)
    predict[title] = predictions[0]
   
    plt.figure(figsize=(10, 6))
    plt.plot(x, y_clean, 'k--', linewidth=2, label='Clean Signal')
    plt.plot(x, data[0,:], 'r--', linewidth=2, label='Noisy Signal')
    plt.plot(x, predict[title], label=f'Prediction', alpha=0.7)
    plt.xlabel("Time (or Moment Index)")
    plt.ylabel("Signal Value")
    plt.title(f"Neural Network Predictions Over Time for {title} Loss")
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.tight_layout()
    plt.show()
# Out:
# Epoch 1/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1
250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4595
# Epoch 231/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4595
# Epoch 232/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4595
# Epoch 233/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4595
# Epoch 234/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4595
# Epoch 235/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4594
# Epoch 236/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4594
# Epoch 237/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4594
# Epoch 238/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4594
# Epoch 239/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4594
# Epoch 240/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4594
# Epoch 241/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4594
# Epoch 242/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4594
# Epoch 243/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4594
# Epoch 244/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4594
# Epoch 245/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4594
# Epoch 246/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4594
# Epoch 247/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4594
# Epoch 248/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4594
# Epoch 249/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4594
# Epoch 250/250
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4594
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
for title in loss_functions.keys():
    error = predict[title] - y_clean
    plt.figure(figsize=(10, 6))
    plt.plot(x, error, label=f'Prediction Error for {title}', alpha=0.7)
    plt.xlabel("Time (or Moment Index)")
    plt.ylabel("Error Value")
    plt.title(f"Prediction Error Over Time for {title} Loss")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y_clean, 'k--', linewidth=2, label='Clean Signal')
plt.plot(x, predict["L1"], label=f'Prediction for L1', alpha=0.7)
plt.plot(x, predict["L2"], label=f'Prediction for L2', alpha=0.7)
plt.xlabel("Time (or Moment Index)")
plt.ylabel("Signal Value")
plt.title(f"Neural Network Predictions Over Time for L1 and L2 Losses")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
x_pdf = np.linspace(0, 10, 1000)
pdf = lognorm.pdf(x_pdf, s=sigma, scale=np.exp(mean))
mean_lognorm = lognorm.mean(s=sigma, scale=np.exp(mean))
median_lognorm = lognorm.median(s=sigma, scale=np.exp(mean))

# Plot the PDF
plt.figure(figsize=(10, 6))
plt.plot(x_pdf, pdf, label='Log-normal PDF', color='blue')
plt.axvline(mean_lognorm, color='red', linestyle='--', label=f'Mean: {mean_lognorm:.2f}')
plt.axvline(median_lognorm, color='green', linestyle='--', label=f'Median: {median_lognorm:.2f}')
plt.xlabel('x')
plt.ylabel('Density')
plt.title('Log-normal Distribution (mu=0, sigma=1)')
plt.legend()
plt.grid(True)
plt.show()

# %%
diff_series = np.array(predict["L2"]-predict["L1"])
diff_mean = np.mean(predict["L2"]-predict["L1"])
mean_rounded = str(round(diff_mean,4))
theoretical_diff = theory_mean-np.exp(mean)

print("Observed Mean Difference: ",diff_mean)
print("Theoretical Difference: ", theoretical_diff)

plt.figure(figsize=(10, 6))
plt.plot(x, diff_series, label=f'Prediction Differences L2 vs L1', alpha=0.7)
plt.hlines(y=diff_mean,label=f'Mean Difference L2 - L1 = {mean_rounded}',xmin=0,xmax=1)
plt.xlabel("Time (or Moment Index)")
plt.ylabel("Signal Value")
plt.title(f"Neural Network Predictions Over Time for{title} Loss")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()
# Out:
# Observed Mean Difference:  0.62282896
# Theoretical Difference:  0.6487212707001282

# %% [markdown]
# TO DO:

# %% [markdown]
# - Hacer lo mismo pero con sin(x) ---> Probar periodicidades distintas (1 donde se haga la primera oscilación, otro donde haya más, etc.)
# - Testear ruido Cauchy con x^2
# - Serie financiera de datos reales ---> observar una diferencia como la observada
# - Objetivo: ver como entrandno con diferentes pérdidas se dan estimaciones distintas pero igualmente válidas. Solo con cambiar la métrica se puede obtener una estimación con unas características específicas u otras.
